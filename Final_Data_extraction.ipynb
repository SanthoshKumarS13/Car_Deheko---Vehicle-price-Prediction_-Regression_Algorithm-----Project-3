# %%
import pandas as pd
import ast

# Load the CSV file
file_path = r"C:\Users\sandy\Downloads\Hyderabad_output_file.csv"  # Adjust this if necessary
df = pd.read_csv(file_path)

# Function to par'se the JSON-like strings into actual dictionaries
def parse_json_column(column):
    return column.apply(lambda x: ast.literal_eval(x))

# Parsing the columns
df['new_car_detail'] = parse_json_column(df['new_car_detail'])
df['new_car_overview'] = parse_json_column(df['new_car_overview'])
df['new_car_feature'] = parse_json_column(df['new_car_feature'])
df['new_car_specs'] = parse_json_column(df['new_car_specs'])

# Extracting details from 'new_car_detail'
df_details = pd.json_normalize(df['new_car_detail'])

# Extracting overview from 'new_car_overview'
df_overview = pd.json_normalize(df['new_car_overview'].apply(lambda x: x.get('top', {})))

# Extracting features from 'new_car_feature'
df_features = pd.json_normalize(df['new_car_feature'].apply(lambda x: x.get('top', {})))

# Extracting specifications from 'new_car_specs'
df_specs = pd.json_normalize(df['new_car_specs'].apply(lambda x: x.get('top', {})))

# Extracting additional data from 'new_car_overview', 'new_car_feature', and 'new_car_specs' if present
df_overview_data = pd.json_normalize(df['new_car_overview'].apply(lambda x: x.get('data', {})))
df_features_data = pd.json_normalize(df['new_car_feature'].apply(lambda x: x.get('data', {})))
df_specs_data = pd.json_normalize(df['new_car_specs'].apply(lambda x: x.get('data', {})))

# Combine all extracted data into a single dataframe
df_final = pd.concat([df_details, df_overview, df_features, df_specs, 
                      df_overview_data, df_features_data, df_specs_data,
                      df['car_links']], axis=1)

# Save the structured data to your specified path
output_file = 'C:/Users/sandy/Desktop/Project_realected_practice/Car_deako/Structed_Hyderabad_cars.csv'
df_final.to_csv(output_file, index=False)

print(f"Structured data saved to {output_file}")
# Out:
# Structured data saved to C:/Users/sandy/Desktop/Project_realected_practice/Car_deako/Structed_Hyderabad_cars.csv

# %%
import pandas as pd
First=pd.read_csv(r'C:/Users/sandy/Desktop/Project_realected_practice/Car_deako/Structed_Hyderabad_cars.csv')
First.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner         oem  \
# 0   0  Petrol  Hatchback  20,000    Automatic        1  1st Owner  Volkswagen
# 1   0  Petrol  Hatchback  85,582       Manual        2  2nd Owner     Hyundai
# 2   0  Petrol        SUV  10,000       Manual        1  1st Owner     Hyundai
# 3   0  Petrol  Hatchback  50,750       Manual        1  1st Owner      Maruti
# 4   0  Petrol        SUV  10,000    Automatic        1  1st Owner    Mahindra
#
#              model  modelYear  ...                             5.2  \
# 0  Volkswagen Polo       2022  ...  {'key': 'Seats', 'value': '5'}
# 1      Hyundai EON       2014  ...                             NaN
# 2    Hyundai Venue       2023  ...                             NaN
# 3    Maruti Baleno       2017  ...  {'key': 'Seats', 'value': '5'}
# 4    Mahindra Thar       2022  ...                             NaN
#
#                                                  0.3  \
# 0  {'heading': 'Comfort & Convenience', 'subHeadi...
# 1  {'heading': 'Comfort & Convenience', 'subHeadi...
# 2  {'heading': 'Comfort & Convenience', 'subHeadi...
# 3  {'heading': 'Comfort & Convenience', 'subHeadi...
# 4  {'heading': 'Comfort & Convenience', 'subHeadi...
#
#                                                  1.3  \
# 0  {'heading': 'Interior', 'subHeading': 'Interio...
# 1  {'heading': 'Interior', 'subHeading': 'Interio...
# 2  {'heading': 'Interior', 'subHeading': 'Interio...
# 3  {'heading': 'Interior', 'subHeading': 'Interio...
# 4  {'heading': 'Interior', 'subHeading': 'Interio...
#
#                                                  2.3  \
# 0  {'heading': 'Exterior', 'subHeading': 'Exterio...
# 1  {'heading': 'Exterior', 'subHeading': 'Exterio...
# 2  {'heading': 'Exterior', 'subHeading': 'Exterio...
# 3  {'heading': 'Exterior', 'subHeading': 'Exterio...
# 4  {'heading': 'Exterior', 'subHeading': 'Exterio...
#
#                                                  3.3  \
# 0  {'heading': 'Safety', 'subHeading': 'Safety', ...
# 1  {'heading': 'Safety', 'subHeading': 'Safety', ...
# 2  {'heading': 'Safety', 'subHeading': 'Safety', ...
# 3  {'heading': 'Safety', 'subHeading': 'Safety', ...
# 4  {'heading': 'Safety', 'subHeading': 'Safety', ...
#
#                                                  4.3  \
# 0  {'heading': 'Entertainment & Communication', '...
# 1                                                NaN
# 2  {'heading': 'Entertainment & Communication', '...
# 3  {'heading': 'Entertainment & Communication', '...
# 4  {'heading': 'Entertainment & Communication', '...
#
#                                                  0.4  \
# 0  {'heading': 'Engine and Transmission', 'subHea...
# 1  {'heading': 'Engine and Transmission', 'subHea...
# 2  {'heading': 'Engine and Transmission', 'subHea...
# 3  {'heading': 'Engine and Transmission', 'subHea...
# 4  {'heading': 'Engine and Transmission', 'subHea...
#
#                                                  1.4  \
# 0  {'heading': 'Dimensions & Capacity', 'subHeadi...
# 1  {'heading': 'Dimensions & Capacity', 'subHeadi...
# 2  {'heading': 'Dimensions & Capacity', 'subHeadi...
# 3  {'heading': 'Dimensions & Capacity', 'subHeadi...
# 4  {'heading': 'Dimensions & Capacity', 'subHeadi...
#
#                                                  2.4  \
# 0  {'heading': 'Miscellaneous', 'subHeading': 'Mi...
# 1  {'heading': 'Miscellaneous', 'subHeading': 'Mi...
# 2  {'heading': 'Miscellaneous', 'subHeading': 'Mi...
# 3  {'heading': 'Miscellaneous', 'subHeading': 'Mi...
# 4  {'heading': 'Miscellaneous', 'subHeading': 'Mi...
#
#                                            car_links
# 0  https://www.cardekho.com/used-car-details/used...
# 1  https://www.cardekho.com/buy-used-car-details/...
# 2  https://www.cardekho.com/used-car-details/used...
# 3  https://www.cardekho.com/buy-used-car-details/...
# 4  https://www.cardekho.com/used-car-details/used...
#
# [5 rows x 53 columns]

# %%
import pandas as pd
import ast

def process_cell(cell):
    if pd.isna(cell):
        return {}
    try:
        data = ast.literal_eval(cell)
        if isinstance(data, dict):
            return data
    except (ValueError, SyntaxError):
        return {}
    return {}

def transform_data(input_file, output_file):
    # Load the CSV file
    data = pd.read_csv(input_file)

    # Apply the function to relevant columns to convert JSON-like strings into dictionaries
    json_columns = data.columns[18:52]
    for col in json_columns:
        data[col] = data[col].apply(process_cell)

    # Initialize a list to hold the structured data rows
    structured_data_rows = []

    # Process each row to extract and organize the structured data
    for index, row in data.iterrows():
        new_row = {}
        specification_count = 1
        
        for col in json_columns:
            cell_data = row[col]
            
            # Type 1 and Type 4: Key-Value pairs
            if 'key' in cell_data:
                new_row[cell_data['key']] = cell_data['value']
            
            # Type 2: Only Value
            elif 'value' in cell_data and 'key' not in cell_data:
                new_row[f'specification{specification_count}'] = cell_data['value']
                specification_count += 1
            
            # Type 3: Heading with list of values
            elif 'heading' in cell_data and 'list' in cell_data:
                values_list = [item['value'] for item in cell_data['list']]
                new_row[cell_data['heading']] = values_list
        
        # Append the new row dictionary to the list of structured data rows
        structured_data_rows.append(new_row)

    # Convert the list of dictionaries to a DataFrame
    structured_data = pd.DataFrame(structured_data_rows)

    # Merge the structured data back with the original data (excluding JSON columns)
    final_data = pd.concat([data.drop(columns=json_columns), structured_data], axis=1)
    
    # Save the final structured data to a new CSV file
    final_data.to_csv(output_file, index=False)

# Usage
input_file = r'C:\Users\sandy\Desktop\Project_realected_practice\Car_deako\Structed_Hyderabad_cars.csv'
output_file = r'C:\Users\sandy\Desktop\Project_realected_practice\Car_deako\structured_data_Hyderabad.csv'
transform_data(input_file, output_file)

# %%
import pandas as pd
First_2=pd.read_csv(r'C:\Users\sandy\Desktop\Project_realected_practice\Car_deako\structured_data_Hyderabad.csv')
First_2.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner         oem  \
# 0   0  Petrol  Hatchback  20,000    Automatic        1  1st Owner  Volkswagen
# 1   0  Petrol  Hatchback  85,582       Manual        2  2nd Owner     Hyundai
# 2   0  Petrol        SUV  10,000       Manual        1  1st Owner     Hyundai
# 3   0  Petrol  Hatchback  50,750       Manual        1  1st Owner      Maruti
# 4   0  Petrol        SUV  10,000    Automatic        1  1st Owner    Mahindra
#
#              model  modelYear  ...   Torque Wheel Size  \
# 0  Volkswagen Polo       2022  ...    175nm        R16
# 1      Hyundai EON       2014  ...   74.5Nm        NaN
# 2    Hyundai Venue       2023  ...  113.8Nm        NaN
# 3    Maruti Baleno       2017  ...    115Nm         16
# 4    Mahindra Thar       2022  ...    320Nm         18
#
#                                Comfort & Convenience  \
# 0  ['Power Steering', 'Power Windows Front', 'Pow...
# 1  ['Power Steering', 'Power Windows Front', 'Rem...
# 2  ['Power Steering', 'Power Windows Front', 'Pow...
# 3  ['Power Steering', 'Power Windows Front', 'Pow...
# 4  ['Power Steering', 'Power Windows Front', 'Low...
#
#                                             Interior  \
# 0  ['Air Conditioner', 'Heater', 'Adjustable Stee...
# 1  ['Air Conditioner', 'Heater', 'Digital Odomete...
# 2  ['Air Conditioner', 'Heater', 'Adjustable Stee...
# 3  ['Air Conditioner', 'Heater', 'Adjustable Stee...
# 4  ['Air Conditioner', 'Heater', 'Adjustable Stee...
#
#                                             Exterior  \
# 0  ['Adjustable Head Lights', 'Fog Lights Front',...
# 1  ['Adjustable Head Lights', 'Manually Adjustabl...
# 2  ['Adjustable Head Lights', 'Power Adjustable E...
# 3  ['Adjustable Head Lights', 'Fog Lights Front',...
# 4  ['Adjustable Head Lights', 'Fog Lights Front',...
#
#                                               Safety  \
# 0  ['Anti Lock Braking System', 'Centeral Locking...
# 1  ['Child Safety Locks', 'Driver Air Bag', 'Day ...
# 2  ['Anti Lock Braking System', 'Brake Assist', '...
# 3  ['Anti Lock Braking System', 'Centeral Locking...
# 4  ['Anti Lock Braking System', 'Brake Assist', '...
#
#                        Entertainment & Communication  \
# 0  ['Radio', 'Speakers Front', 'Speakers Rear', '...
# 1                                                NaN
# 2  ['Radio', 'Speakers Front', 'Speakers Rear', '...
# 3  ['Radio', 'Audio System Remote Control', 'Spea...
# 4  ['Radio', 'Speakers Front', 'Speakers Rear', '...
#
#                              Engine and Transmission  \
# 0  ['Others', '1.0L TSI Petrol', '999', '108.62bh...
# 1  ['Red', 'Petrol Engine', '814', '55.2bhp@5500r...
# 2  ['Others', '1.2 Kappa Petrol', '1197', '81.80b...
# 3  ['Red', 'VVT Petrol Engine', '1197', '83.1bhp@...
# 4  ['Others', 'mStallion 150 TGDi Engine', '1997'...
#
#                                Dimensions & Capacity  \
# 0  ['3971mm', '1682mm', '1469mm', '2470mm', '1457...
# 1  ['3495mm', '1550mm', '1500mm', '2380mm', '1386...
# 2   ['3995mm', '1770mm', '1617mm', '2500mm', '1106']
# 3  ['3995mm', '1745mm', '1510mm', '2520mm', '1505...
# 4  ['3985mm', '1855mm', '1844mm', '2450mm', '1520...
#
#                                        Miscellaneous
# 0  ['6 Speed', 'FWD', '5', 'Electronic', '4.9', '...
# 1  ['5 Speed', 'FWD', '5', 'Power', '4.6 metres',...
# 2  ['5-Speed', '5', 'Power', 'Disc', 'Drum', 'Tub...
# 3  ['5 Speed', 'FWD', '5', 'Power', '4.9 meters',...
# 4  ['6 Speed', '4X4', '4', 'Power', 'Disc', 'Drum...
#
# [5 rows x 51 columns]

# %%
import pandas as pd

# Load the structured CSV file
file_path = r'C:\Users\sandy\Desktop\Project_realected_practice\Car_deako\structured_data_Hyderabad.csv'
data = pd.read_csv(file_path)

# List of columns that contain lists of values
list_columns = [
    'Interior',
    'Safety',
    'Miscellaneous',
]

# Function to split list values into separate columns
def split_list_into_columns(row, col_name):
    values = row[col_name]
    if pd.isna(values):
        return {}
    
    values = values.strip('[]').split(',')
    values = [v.strip().strip("'") for v in values]
    
    split_columns = {f'{col_name}{i+1}': values[i] for i in range(len(values))}
    return split_columns

# Apply the function to each row and update the dataframe
for col in list_columns:
    new_columns = data.apply(lambda row: pd.Series(split_list_into_columns(row, col)), axis=1)
    data = pd.concat([data, new_columns], axis=1)
    data.drop(columns=[col], inplace=True)

# Save the updated dataframe to a new CSV file
output_file_path = r'C:\Users\sandy\Desktop\Project_realected_practice\Car_deako\Hyderabad.csv'
data.to_csv(output_file_path, index=False)

output_file_path
# Out:
# 'C:\\Users\\sandy\\Desktop\\Project_realected_practice\\Car_deako\\Hyderabad.csv'

# %%
import pandas as pd
import ast

# Step 1: Load the data
df = pd.read_csv(r"C:\Users\sandy\Desktop\Project_realected_practice\Car_deako\Hyderabad.csv")
df
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback    20,000    Automatic        1  1st Owner
# 1      0  Petrol  Hatchback    85,582       Manual        2  2nd Owner
# 2      0  Petrol        SUV    10,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback    50,750       Manual        1  1st Owner
# 4      0  Petrol        SUV    10,000    Automatic        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1478   0  Diesel        SUV    60,000       Manual        1  1st Owner
# 1479   0  Diesel      Sedan    50,000    Automatic        1  1st Owner
# 1480   0  Diesel      Sedan  1,20,000    Automatic        3  3rd Owner
# 1481   0  Diesel        SUV    50,000    Automatic        2  2nd Owner
# 1482   0  Diesel        MUV  1,00,000       Manual        1  1st Owner
#
#              oem            model  modelYear  ...  Miscellaneous13  \
# 0     Volkswagen  Volkswagen Polo       2022  ...              NaN
# 1        Hyundai      Hyundai EON       2014  ...              NaN
# 2        Hyundai    Hyundai Venue       2023  ...              NaN
# 3         Maruti    Maruti Baleno       2017  ...                5
# 4       Mahindra    Mahindra Thar       2022  ...              NaN
# ...          ...              ...        ...  ...              ...
# 1478    Mahindra  Mahindra XUV500       2013  ...                5
# 1479      Jaguar        Jaguar XF       2014  ...                4
# 1480         BMW     BMW 5 Series       2018  ...                4
# 1481        Tata       Tata Nexon       2019  ...              NaN
# 1482      Toyota    Toyota Innova       2015  ...                5
#
#      Miscellaneous14 Miscellaneous2 Miscellaneous3  Miscellaneous4  \
# 0                NaN            FWD              5      Electronic
# 1                NaN            FWD              5           Power
# 2                NaN              5          Power            Disc
# 3         339-litres            FWD              5           Power
# 4                NaN            4X4              4           Power
# ...              ...            ...            ...             ...
# 1478             NaN            FWD              7           Power
# 1479      540-litres            RWD              5           Power
# 1480      520-litres            RWD              5           Power
# 1481             NaN            FWD              5           Power
# 1482      300-litres            RWD              7           Power
#
#       Miscellaneous5       Miscellaneous6       Miscellaneous7 Miscellaneous8  \
# 0                4.9                 Disc                 Drum       Tubeless
# 1         4.6 metres                 Disc                 Drum       135 Kmph
# 2               Drum             Tubeless               Radial              5
# 3         4.9 meters                 Disc                 Drum       180 Kmph
# 4               Disc                 Drum               Radial       Tubeless
# ...              ...                  ...                  ...            ...
# 1478      5.6 metres  Disc & Caliper Type  Disc & Caliper Type       175 kmph
# 1479     5.75 metres                 Disc                 Disc       250 Kmph
# 1480             5.6      Ventilated Disc      Ventilated Disc        235kmph
# 1481            5.1m                 Disc                 Drum    154.19 kmph
# 1482      5.4 metres      Ventilated Disc                 Drum       155 Kmph
#
#      Miscellaneous9
# 0            Radial
# 1        19 Seconds
# 2               NaN
# 3     12.36 seconds
# 4                18
# ...             ...
# 1478   12.5 Seconds
# 1479    6.4 Seconds
# 1480            7.5
# 1481  13.25 Seconds
# 1482   13.3 Seconds
#
# [1483 rows x 118 columns]
